# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('/content/data_after_feature_engg.csv')

# %%
df = df.drop(columns = 'Unnamed: 0')

# %%
df.head()
# Out:
#    Facing  No_Bedroom  No_Bathroom  No_Balcony  Corner_Property  Furnishing  \
# 0     1.0           2          2.0           1                0         3.0
# 1     3.0           2          2.0           1                0         3.0
# 2     4.0           2          2.0           1                1         2.0
# 3     0.0           2          2.0           2                1         2.0
# 4     2.0           2          2.0           4                1         1.0
#
#    Price_in_Crore  price_Per_Sqft_converted  given_area_in_sqft  floor_number  \
# 0            0.61                    8840.0                 690            14
# 1            0.70                   10144.0                 690             8
# 2            0.71                    8492.0                 836             9
# 3            1.55                   12301.0                1260             9
# 4            1.30                    9516.0                1366             1
#
#    ...  Overlooking_sea facing  Overlooking_club  Overlooking_park/garden  \
# 0  ...                       0                 0                        1
# 1  ...                       0                 0                        1
# 2  ...                       0                 1                        1
# 3  ...                       0                 1                        1
# 4  ...                       0                 1                        1
#
#    Overlooking_pool  Overlooking_lake facing  Overlooking_NA  flat_age  \
# 0                 0                        0               0         3
# 1                 0                        0               0         3
# 2                 0                        0               0         3
# 3                 1                        0               0         1
# 4                 1                        0               0         3
#
#    sector_num  luxury_score                                          Text_info
# 0          90            88  Green court society, which is bang on 60-Meter...
# 1          90            83  Green court society, which is bang on 60-Meter...
# 2          70            99  Available for sale 2 bhk semi furnished in pyr...
# 3          68            73  Looking for a 2 bhk property for sale in gurga...
# 4         107            81  This 2 bhk apartment is available for sale in ...
#
# [5 rows x 30 columns]

# %%
from ydata_profiling import ProfileReport

profile = ProfileReport(df, title='Pandas Profiling Report', explorative=True)

profile.to_file("output_report.html")
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
